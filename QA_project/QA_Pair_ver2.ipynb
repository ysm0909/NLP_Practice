# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # QA Pair 생성 PDF 업로드

# %%
from unstructured.partition.pdf import partition_pdf


def extract_pdf_elements(filepath):
    """
    PDF 파일에서 이미지, 테이블, 그리고 텍스트 조각을 추출합니다.
    path: 이미지(.jpg)를 저장할 파일 경로
    fname: 파일 이름
    """
    return partition_pdf(
        filename=filepath,
        extract_images_in_pdf=False,  # PDF 내 이미지 추출 활성화
        infer_table_structure=False,  # 테이블 구조 추론 활성화
        chunking_strategy="by_title",  # 제목별로 텍스트 조각화
        max_characters=3000,  # 최대 문자 수
        new_after_n_chars=2800,  # 이 문자 수 이후에 새로운 조각 생성
        combine_text_under_n_chars=1200,  # 이 문자 수 이하의 텍스트는 결합
    )

# %%
# PDF 파일 로드
elements = extract_pdf_elements("D:/[24]ICT_Practice/teddy__/file/(2024)portmis_guidebook.pdf")

# %%
# 로드한 TEXT 청크 수
len(elements)
# Out:
# 27

# %%
print(elements[2])
# Out:
# 첨부서류 제출
#
# 국적증서, 국제총톤수증서 등 관련 서류 체출 (FAX 또는 E-Mail)
#
# 7
#
# 오류통보 (반려)
#
# 업무담당자 : 민원 신청 내용에 오류가 있는 경우 오류내용 입력 후 (오류)처리
#
# 5
#
# 신청정보 처리 현황 조회
#
# 신청 내역에 대한 진행상태 확인
#
# 민원인 : 오류 내용 확인 후 신청정보를 수정하여 재신고
#
# 6
#
# 선박제원 신고 내용 확인
#
# (담당자) 선박제원 신청정보 심사 후 수리 또는 오류 통보
#
# 8
#
# 신청정보 승인
#
# (담당자) 선박제원 신청내용에 이상이 없으면 완료 처리
#
# OK
#
# 9
#
# 선박제원 신청 완료
#
# 10
#
# 입항(출항) 신고 신청
#
# 선박 입항(출항)신고 시작
#
# 11
#
# 포트미스 신고 업무 안내
#
# 외항선 민원신고 절차
#
# 선박운항
#
# 1 외항입항신고 (최초) / (변경)
#
# 1-1 승무원 / 승객명부
#
# 담당자(수리)
#
# 2-1 강제도선면제 신청
#
# 2-2 예선사용면제 신청
#
# 담당자(수리)
#
# 3 선박평형수신고
#
# 4 선박보안 정보통보
#
# 담당자(수리)
#
# 10 외항입항신고 (최종)
#
# 담당자(수리)
#
# 5-1 저속운항선박 지원신청
#
# AIS검증 (적합/부적합)
#
# 5-2 저속운항선박 인센티브 신청
#
# 담당자(수리)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 외항
#
# 입항
#
# 신고
#
# 항만시설
#
# 6 항만시설사용허가 신청서(선석신청)
#
# 담당자(허가)
#
# 7 항만시설사용료(정박료)
#
# 면제 신청
#
# 담당자(승인)
#
# 10
#
# 11
#
# 담당자(반려)
#
# 담당자(반려)
#
# 8 위험물 반입신고 / 위험물 일람표신고
#
# 9 통합화물신고
#
# 11 항만시설사용 허가신고(화물료)
#
# 12 화물료 대납 경비청구
#
# 위험물/화물
#
# 담당자(수리)
#
# 담당자(수리)
#
# 담당자(수리)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 1 외항출항신고 (최초) / (변경)
#
# 2-1 강제도선면제 신청
#
# 1-1 승무원 / 승객명부
#
# 2-2 예선사용면제 신청
#
# 10 외항출항신고 (최종)
#
# 선박운항
#
# 담당자(수리)
#
# 담당자(수리)
#
# 담당자(반려)
#
# 담당자(수리)
#
# 담당자(반려)
#
# 외항
#
# 출항
#
# 신고
#
# 항만시설
#
# 10
#
# 11
#
# 8 위험물 반입신고 / 위험물 일람표신고
#
# 9 통합화물신고
#
# 11 항만시설사용 허가신고(화물료)
#
# 12 화물료 대납 경비청구
#
# 위험물/화물
#
# 담당자(수리)
#
# 담당자(수리)
#
# 담당자(수리)
#
# 담당자(반려)
#
# 담당자(반려)
#
# 12 • PORT-MIS
#
# 13
#
# 포트미스 신고 업무 안내
#
# 내항선 민원신고 절차
#
# 기타 민원신고
#
# 1 내항입항신고 (최초) / (변경) / (최종)

# %% [markdown]
# # QA Pair 생성

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    """Context information is below. You are only aware of this context and nothing else.
---------------------

{context}

---------------------
Given this context, generate only questions based on the below query.
You are an Teacher/Professor in {domain}.
Your task is to provide exactly **{num_questions}** question(s) for an upcoming quiz/examination.
You are not to provide more or less than this number of questions.
The question(s) should be diverse in nature across the document.
The purpose of question(s) is to test the understanding of the students on the context information provided.
You must also provide the answer to each question. The answer should be based on the context information provided only.

Restrict the question(s) to the context information provided only.
QUESTION and ANSWER should be written in Korean. response in JSON format which contains the `question` and `answer`.
DO NOT USE List in JSON format.
ANSWER should be a complete sentence.

The following is additional information about the {domain}.
'''
Port-MIS(항만운영정보시스템, Port Management Information System)는 전국의 28개 무역항에 대하여 선박의 입항신고, 항만 내 시설사용, 관제사항, 화물반출입, 세입징수, 출항신고 등 모든 항만운영업무 및 민원업무를 처리하는 시스템입니다.
'''

#Format:
```json
{{
    "QUESTION": "월정료선박 사용신청을 할 때 1년 선납시 어떤 혜택을 받을 수 있습니까?",
    "ANSWER": "월정료선박 사용신청을 할 때 1년 선납시 사용료 10%를 할인받을 수 있습니다."
}},
{{
    "QUESTION": "대한민국 항만에 입항하기 위해 선박은 어떤 정보를 제출해야 하나요?",
    "ANSWER": "대한민국 항만에 입항하기 위해 선박은 선명, IMO 번호, 국적, 총톤수, 입항항만, 입항예정시각, 선박보안등급, 국제선박보안증서 번호와 유효기간, 발급기관명, 그리고 최근 기항한 10개 항만에 대한 보안정보를 제출해야 합니다."
}},
{{
    "QUESTION": "선박수리신고를 완료한 후 어떤 과정을 거치게 됩니까?",
    "ANSWER": "선박수리신고를 완료한 후, 업무담당자는 민원 신고 문서를 심사하고, 이를 허가하거나 오류를 통보(반려)합니다. 반려된 경우, 민원인은 반려 내용을 확인할 수 있도록 반려 사유를 입력해야 합니다."
}}
```
"""
)

# %%
import json
from langchain_openai import ChatOpenAI
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler


def custom_json_parser(response):
    json_string = response.content.strip().removeprefix("```json\n").removesuffix("\n```").strip()
    json_string = f'[{json_string}]'
    return json.loads(json_string)

chain = (
    prompt
    | ChatOpenAI(
        model="gpt-4o",
        temperature=0,
        streaming=True,
        callbacks=[StreamingStdOutCallbackHandler()],
    )
    | custom_json_parser
)  # 체인을 구성합니다.

qa_pair = []

for element in elements[1:]:
    if element.text:
        qa_list = chain.invoke(
            {"context": element.text, "domain": "AI", "num_questions": "4"}
        )
        for qa in qa_list:
            qa_modified = {
                "instruction": qa["QUESTION"],
                "input": element.text,  # element의 텍스트를 input에 저장
                "output": qa["ANSWER"],
            }
            qa_pair.append(qa_modified)
# Out:
# ```json
# {
#     "QUESTION": "포트미스 회원가입 절차에서 사용 업체 등록 신청을 위해 제출해야 하는 서류는 무엇인가요?",
#     "ANSWER": "포트미스 회원가입 절차에서 사용 업체 등록 신청을 위해 사업자 등록증을 제출해야 합니다. 이 서류는 홈페이지에서 스캔 파일을 업로드하거나 FAX 또는 E-Mail로 제출할 수 있습니다."
# },
# {
#     "QUESTION": "포트미스에서 선박제원 등록(변경) 절차를 시작하기 위해 가장 먼저 해야 할 일은 무엇인가요?",
#     "ANSWER": "포트미스에서 선박제원 등록(변경) 절차를 시작하기 위해 가장 먼저 해야 할 일은 포트미스 회원가입을 완료하는 것입니다."
# },
# {
#     "QUESTION": "포트미스에서 민간운영 프로그램을 이용할 때 발생하는 요금은 어떻게 결정되나요?",
#     "ANSWER": "포트미스에서 민간운영 프로그램을 이용할 때 발생하는 요금은 사용 데이터량에 따라 결정됩니다."
# },
# {
#     "QUESTION": "포트미스 회원가입 절차에서 신청정보가 승인된 후, 사용자는 어떤 단계로 넘어가게 되나요?",
#     "ANSWER": "포트미스 회원가입 절차에서 신청정보가 승인된 후, 사용자는 회원가입이 완료되며 발급된 사용자 ID로 서비스를 이용할 수 있습니다."
# }
# ``````json
# {
#     "QUESTION": "선박제원 신청정보에 오류가 있는 경우, 민원인은 어떤 절차를 따라야 합니까?",
#     "ANSWER": "선박제원 신청정보에 오류가 있는 경우, 민원인은 오류 내용을 확인한 후 신청정보를 수정하여 재신고해야 합니다."
# },
# {
#     "QUESTION": "외항선의 입항신고 절차에서 '저속운항선박 지원신청'은 어떤 단계에 포함됩니까?",
#     "ANSWER": "외항선의 입항신고 절차에서 '저속운항선박 지원신청'은 5-1 단계에 포함됩니다."
# },
# {
#     "QUESTION": "항만시설사용허가 신청서(선석신청)는 어떤 단계에서 담당자의 허가를 받아야 합니까?",
#     "ANSWER": "항만시설사용허가 신청서(선석신청)는 6단계에서 담당자의 허가를 받아야 합니다."
# },
# {
#     "QUESTION": "선박제원 신청내용에 이상이 없을 경우, 담당자는 어떤 처리를 합니까?",
#     "ANSWER": "선박제원 신청내용에 이상이 없을 경우, 담당자는 완료 처리를 합니다."
# }
# ``````json
# {
#     "QUESTION": "외항선 입항신고를 위해 접속할 수 있는 프로그램은 무엇인가요?",
#     "ANSWER": "외항선 입항신고를 위해 접속할 수 있는 프로그램은 해양수산부의 PORT-MIS(www.portmis.go.kr), KL-NET(프리즘 3.0, https://www.plism.com), 그리고 KTNET(ulogishub, https://www.ulogishub.com)입니다."
# },
# {
#     "QUESTION": "내항출항신고는 어떤 경우에 최초, 변경, 최종으로 나뉘어 신고되나요?",
#     "ANSWER": "내항출항신고는 선박이 처음 출항할 때 최초로 신고되고, 출항 정보에 변경이 있을 때 변경 신고가 이루어지며, 실제 출항 후 최종 신고가 이루어집니다."
# },
# {
#     "QUESTION": "항만시설사용료(정박료) 면제 신청은 어떤 경우에 이루어질 수 있나요?",
#     "ANSWER": "항만시설사용료(정박료) 면제 신청은 항만시설사용허가 신청서(선석신청)와 관련하여 이루어질 수 있습니다."
# },
# {
#     "QUESTION": "위험물 반입신고는 어떤 절차를 거쳐야 하나요?",
#     "ANSWER": "위험물 반입신고는 신고 후 담당자의 승인을 받아야 합니다."
# }
# ``````json
# {
#     "QUESTION": "승무원/승객명부 신고 시 어떤 정보가 포함되어야 하나요?",
#     "ANSWER": "승무원/승객명부 신고 시 성명, 국적, 승하선 일자, 승무원직명, 여권번호 또는 선원수첩번호 등의 인적사항이 포함되어야 합니다."
# },
# {
#     "QUESTION": "입항신고 시 승무원/승객명부를 작성할 때 어떤 절차를 따라야 하나요?",
#     "ANSWER": "입항신고 시 출입국정보 인원수에 맞게 승무원/승객의 명부 리스트를 작성하여 신고하고, 첨부서류를 제출해야 합니다."
# },
# {
#     "QUESTION": "민원 신고 문서가 반려된 경우 민원인은 어떻게 해야 하나요?",
#     "ANSWER": "민원 신고 문서가 반려된 경우, 민원인은 오류 내용을 확인한 후 신청정보를 수정하여 재신고해야 합니다."
# },
# {
#     "QUESTION": "강제도선 면제신청을 할 수 있는 조건은 무엇인가요?",
#     "ANSWER": "강제도선 면제신청을 할 수 있는 조건은 1년 이내 4회 이상 또는 3년 이내 9회 이상 승선한 선장과 선박일 경우입니다."
# }
# ``````json
# {
#     "QUESTION": "강제도선 면제신청을 하기 위해 필요한 정보는 무엇인가요?",
#     "ANSWER": "강제도선 면제신청을 하기 위해 필요한 정보는 선원수첩번호, 호출부호, 총톤수, 선박종류, 입출항이력 등입니다."
# },
# {
#     "QUESTION": "민원인이 예선사용 면제신청을 반려받았을 때, 어떤 절차를 따라야 하나요?",
#     "ANSWER": "민원인이 예선사용 면제신청을 반려받았을 때, 오류 내용을 확인 후 신청정보를 수정하여 재신고해야 합니다."
# },
# {
#     "QUESTION": "선박평형수 신고를 위해 접속해야 하는 웹사이트는 어디인가요?",
#     "ANSWER": "선박평형수 신고를 위해 접속해야 하는 웹사이트는 해양수산부(포트미스) www.portmis.go.kr, KL-NET(프리즘 3.0) https://www.plism.com, KTNET(ulogishub) https://www.ulogishub.com 입니다."
# },
# {
#     "QUESTION": "업무담당자가 민원 신고 문서를 심사한 후 이상이 없을 경우 어떤 처리를 하나요?",
#     "ANSWER": "업무담당자가 민원 신고 문서를 심사한 후 이상이 없을 경우 수리처리를 합니다."
# }
# ``````json
# {
#     "QUESTION": "외항선 입항 신고 시 선박평형수 신고 대상 선박은 어떤 종류의 선박입니까?",
#     "ANSWER": "외항선 입항 신고 시 선박평형수 신고 대상 선박은 외국적의 모든 여객선 및 총톤수 500톤 이상 화물선, 이동식 해상구조물입니다."
# },
# {
#     "QUESTION": "선박보안정보 통보 신고 시 어떤 정보를 신고해야 합니까?",
#     "ANSWER": "선박보안정보 통보 신고 시 보안증서번호 및 유효기간, 보안증서 발급기관 및 국가, 입항전 기항지 정보를 신고해야 합니다."
# },
# {
#     "QUESTION": "저속운항선박지원신청의 대상 선박은 어떤 조건을 만족해야 합니까?",
#     "ANSWER": "저속운항선박지원신청의 대상 선박은 3,000톤 이상의 외항선으로, 부산, 인천, 여수, 광양, 울산 등 일정 지역을 일정한 속도 이하(10~12노트)로 운항해야 합니다."
# },
# {
#     "QUESTION": "민원인이 외항선 입항 신고를 할 때 오류가 발생하면 어떤 절차를 따라야 합니까?",
#     "ANSWER": "민원인이 외항선 입항 신고를 할 때 오류가 발생하면, 업무담당자가 오류 내용을 입력하여 오류 처리하고, 민원인은 오류 내용을 확인한 후 신청 정보를 수정하여 재신고해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "외항선 입항신고는 언제까지 해야 하나요?",
#     "ANSWER": "외항선 입항신고는 선박 입항 전까지 입항 예정정보를 신고(최초)하고, 실제 선박 입,출항 후 (최종)신고를 해야 합니다."
# },
# {
#     "QUESTION": "저속운항선박 인센티브 신청을 위해 필요한 조건은 무엇인가요?",
#     "ANSWER": "저속운항선박 인센티브 신청을 위해서는 해당 년도에 1회 이상 저속운항 신청 이력이 있어야 하며, 해당 년도 입항횟수 대비 저속운항적합 비율이 60% 이상이어야 합니다."
# },
# {
#     "QUESTION": "저속운항선박 지원신청을 할 때 입력해야 하는 정보는 무엇인가요?",
#     "ANSWER": "저속운항선박 지원신청을 할 때는 업체정보, 선박정보 등 신고와 신청내용-시작(도착)지점일시 등을 입력해야 합니다."
# },
# {
#     "QUESTION": "AIS 데이터 자동 검증의 목적은 무엇인가요?",
#     "ANSWER": "AIS 데이터 자동 검증의 목적은 AIS 자료를 바탕으로 선박 항로 및 속도를 자동 검증하는 것입니다."
# }
# ``````json
# {
#     "QUESTION": "저속운항선박 지원신청을 완료하기 위해 어떤 단계를 거쳐야 하나요?",
#     "ANSWER": "저속운항선박 지원신청을 완료하기 위해서는 신고 프로그램 접속, 외항선 입항 신고, 저속운항선박 지원신청, 신고 문서검토 및 저장, AIS 데이터 자동 검증, 민원 신고 완료 단계를 거쳐야 합니다."
# },
# {
#     "QUESTION": "저속운항선박 인센티브 신청은 언제 할 수 있나요?",
#     "ANSWER": "저속운항선박 인센티브 신청은 별도로 공지된 신청기간에 할 수 있습니다."
# },
# {
#     "QUESTION": "항만시설사용허가신청서(선석신청)를 제출할 때 어떤 정보를 신고해야 하나요?",
#     "ANSWER": "항만시설사용허가신청서(선석신청)를 제출할 때 사용 시설코드, 사용목적, 사용기간, 양하·적하 화물 내용 등을 신고해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용허가신청서(선석신청) 신고 후 담당자가 반려 처리한 경우 민원인은 어떻게 해야 하나요?",
#     "ANSWER": "항만시설사용허가신청서(선석신청) 신고 후 담당자가 반려 처리한 경우 민원인은 반려 내용을 확인하고 신고서를 수정하여 재신고해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "항만시설사용허가신청서(선석신청)를 반려 처리할 때, 업무담당자는 어떤 조치를 취해야 합니까?",
#     "ANSWER": "업무담당자는 민원 신청 문서를 심사 후 반려 처리할 때, 민원인이 반려 내용을 확인할 수 있도록 반려 사유를 입력해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용료(정박료) 면제신청을 할 때, 면제 사유 중 '접안시설 부족'을 선택한 경우 추가로 입력해야 하는 정보는 무엇입니까?",
#     "ANSWER": "면제 사유 중 '접안시설 부족'을 선택한 경우에는 '선 접안 선박'에 대한 정보를 입력해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용료(정박료) 면제신청을 위해 필요한 증빙서류는 언제 제출해야 합니까?",
#     "ANSWER": "항만시설사용료(정박료) 면제신청을 위해 필요한 증빙서류는 면제 사유를 선택한 뒤 제출해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용허가신청서(선석신청) 신고 완료 후 다음 단계는 무엇입니까?",
#     "ANSWER": "항만시설사용허가신청서(선석신청) 신고 완료 후 다음 단계는 민원 신고 완료입니다."
# }
# ``````json
# {
#     "QUESTION": "위험물을 무역항의 수상구역으로 반입할 때 신고는 언제까지 해야 합니까?",
#     "ANSWER": "위험물을 무역항의 수상구역으로 반입할 때는 반입 24시간 전에 신고해야 합니다."
# },
# {
#     "QUESTION": "민원 신고 문서가 반려된 경우 민원인은 어떤 절차를 따라야 합니까?",
#     "ANSWER": "민원 신고 문서가 반려된 경우, 민원인은 반려 내용을 확인하고 신고서를 수정하여 재신고해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용허가 및 실적정보에 면제코드는 어떻게 반영됩니까?",
#     "ANSWER": "항만시설사용허가 및 실적정보에 면제코드는 담당자가 승인하면 자동으로 반영됩니다."
# },
# {
#     "QUESTION": "위험물 반입신고를 위해 접속할 수 있는 프로그램은 무엇입니까?",
#     "ANSWER": "위험물 반입신고를 위해 접속할 수 있는 프로그램은 해양수산부의 PORT-MIS, KL-NET의 프리즘 3.0, 그리고 KTNET의 ulogishub입니다."
# }
# ``````json
# {
#     "QUESTION": "통합화물신고는 어떤 정보를 포함해야 하나요?",
#     "ANSWER": "통합화물신고는 선박에 실은 모든 화물에 관하여 어떤 화물인지, 누가 보낸 건지, 누구에게 보내는 건지, 언제 선적이 되는지 등의 화물에 관한 모든 정보를 B/L 번호 단위로 신고해야 합니다."
# },
# {
#     "QUESTION": "외항 입항(출항) 신고는 언제까지 완료해야 하나요?",
#     "ANSWER": "외항 입항(출항) 신고는 선박 입,출항 24시간 전까지 입,출항 예정정보를 신고해야 합니다."
# },
# {
#     "QUESTION": "항만시설사용신고는 어떤 내용을 바탕으로 신고하나요?",
#     "ANSWER": "항만시설사용신고는 통합화물신고를 바탕으로 하역구분, 운임톤/개수, 할인 (면제)사유, 사용료 등을 신고합니다."
# },
# {
#     "QUESTION": "민원 신고 문서가 수리되기 위해 어떤 절차를 거쳐야 하나요?",
#     "ANSWER": "민원 신고 문서가 수리되기 위해서는 업무담당자가 민원 신고 문서를 심사한 후 이상이 없으면 수리처리합니다."
# }
# ``````json
# {
#     "QUESTION": "통합화물신고(적하목록)와 외항선입항(출항)신고, 항만시설 사용신고(화물료) 신고가 모두 완료되었을 때, 다음 단계는 무엇입니까?",
#     "ANSWER": "통합화물신고(적하목록)와 외항선입항(출항)신고, 항만시설 사용신고(화물료) 신고가 모두 완료되었을 때, 다음 단계는 담당자가 민원 신고문서를 확인(수리)하는 것입니다."
# },
# {
#     "QUESTION": "화물료 대납경비 청구 신청은 언제 수행됩니까?",
#     "ANSWER": "화물료 대납경비 청구 신청은 화물료 대납월 이후 익월 20일에 수행됩니다."
# },
# {
#     "QUESTION": "PORT-MIS 시스템에서 화물료 대납경비 청구를 신청할 때 필요한 정보는 무엇입니까?",
#     "ANSWER": "PORT-MIS 시스템에서 화물료 대납경비 청구를 신청할 때 필요한 정보는 은행, 계좌번호, 예금주, 통장사본 등입니다."
# },
# {
#     "QUESTION": "화물료 대납경비 청구 시 수수료는 어떻게 청구됩니까?",
#     "ANSWER": "화물료 대납경비 청구 시 수수료는 당월에 수납한 금액의 3%를 익월에 청구하며, 보안료는 6.8%를 청구합니다."
# }
# ``````json
# {
#     "QUESTION": "국가관리 연안항이란 무엇을 주목적으로 하는 항만인가요?",
#     "ANSWER": "국가관리 연안항은 국가안보 또는 영해관리에 중요하거나 기상악화 등 유사시 선박의 대피를 주목적으로 하는 항만입니다."
# },
# {
#     "QUESTION": "화물료대납 경비는 언제 지급되나요?",
#     "ANSWER": "화물료대납 경비는 대납 월 이후 익월 말일에 지급됩니다."
# },
# {
#     "QUESTION": "민원 신고서에 오류가 있는 경우 업무담당자는 어떤 절차를 밟아야 하나요?",
#     "ANSWER": "민원 신고서에 오류가 있는 경우 업무담당자는 오류내용을 입력한 후 반려 처리해야 합니다."
# },
# {
#     "QUESTION": "연안항신고를 통해 어떤 내용을 한번에 신고할 수 있나요?",
#     "ANSWER": "연안항신고를 통해 입항정보, 출항정보, 항만시설 사용신청을 한번에 신고할 수 있습니다."
# }
# ``````json
# {
#     "QUESTION": "서북도서출항신고를 하기 위해 필요한 첨부 서류는 무엇입니까?",
#     "ANSWER": "서북도서출항신고를 하기 위해 필요한 첨부 서류는 선원명부, 선박검사증서, 선박국적증서입니다."
# },
# {
#     "QUESTION": "연안항 화물료 신고 절차에서 담당자의 승인이 필요한 단계는 몇 번째입니까?",
#     "ANSWER": "연안항 화물료 신고 절차에서 담당자의 승인이 필요한 단계는 6번째와 8번째입니다."
# },
# {
#     "QUESTION": "월정료선박 사용신청을 할 때 포트미스에서 어떤 메뉴를 통해 신청할 수 있습니까?",
#     "ANSWER": "월정료선박 사용신청을 할 때 포트미스에서 '항만시설' 메뉴를 통해 신청할 수 있습니다."
# },
# {
#     "QUESTION": "서북도서출항신고를 완료한 후 민원인은 어떤 단계를 거쳐야 합니까?",
#     "ANSWER": "서북도서출항신고를 완료한 후 민원인은 신고 문서검토 및 저장 단계를 거쳐야 합니다."
# }
# ``````json
# {
#     "QUESTION": "선박수리신고 신청 시 필요한 첨부서류는 무엇인가요?",
#     "ANSWER": "선박수리신고 신청 시 필요한 첨부서류는 작업 계획서와 작업자의 자격증 사본입니다."
# },
# {
#     "QUESTION": "선박수리허가 신청이 필요한 경우는 언제인가요?",
#     "ANSWER": "선박수리허가 신청이 필요한 경우는 용접(발열)작업 시 폭발위험이 있는 위험물 운반선(톤수 제한 없음)과 그 외 선박(총톤수 20톤 이상)이 선박 내 위험구역에서 작업할 경우입니다."
# },
# {
#     "QUESTION": "민원 신고서에 오류가 있는 경우 업무담당자는 어떻게 처리하나요?",
#     "ANSWER": "민원 신고서에 오류가 있는 경우 업무담당자는 오류내용을 입력 후 반려 처리합니다."
# },
# {
#     "QUESTION": "포트미스(Port-MIS) 시스템의 주요 기능은 무엇인가요?",
#     "ANSWER": "포트미스(Port-MIS) 시스템의 주요 기능은 선박의 입항신고, 항만 내 시설사용, 관제사항, 화물반출입, 세입징수, 출항신고 등 모든 항만운영업무 및 민원업무를 처리하는 것입니다."
# }
# ``````json
# {
#     "QUESTION": "민원 신고문서가 반려된 경우, 민원인은 어떤 정보를 확인할 수 있습니까?",
#     "ANSWER": "민원 신고문서가 반려된 경우, 민원인은 반려 내용을 확인할 수 있도록 반려 사유를 확인할 수 있습니다."
# },
# {
#     "QUESTION": "상계 신청은 주로 어느 기관에서 사용되며, 국고 환급이 불가능한 경우는 어떤 경우입니까?",
#     "ANSWER": "상계 신청은 주로 지방해양수산청에서 사용되며, 국고 환급은 불가능한 경우가 많습니다. 단, 피치 못한 사정일 경우에는 환급도 가능합니다."
# },
# {
#     "QUESTION": "과오납 상계 등록 후 업무담당자는 어떤 절차를 밟아야 합니까?",
#     "ANSWER": "과오납 상계 등록 후 업무담당자는 민원인에게 해당 건에 대한 상계처리 완료되었다고 통보해야 합니다."
# },
# {
#     "QUESTION": "PORT-MIS 시스템을 통해 상계/환급 신청을 하려면 어떤 메뉴를 통해 접근해야 합니까?",
#     "ANSWER": "PORT-MIS 시스템을 통해 상계/환급 신청을 하려면 'PORT-MIS 신고 → 조회/발급/사용료 → 사용료 → 상계/환급신청' 메뉴를 통해 접근해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS의 정의는 무엇인가요?",
#     "ANSWER": "PORT-MIS는 전국 무역항(31개) 선박의 입항·출항, 항만이용 및 항만물류, 해운·선원·선박 등의 민원사무 처리 및 정보관리에 관한 업무지원 시스템입니다."
# },
# {
#     "QUESTION": "과오납 환급 신청 시 민원인이 제출해야 하는 서류는 무엇인가요?",
#     "ANSWER": "과오납 환급 신청 시 민원인은 통장사본을 기관(지방해양수산청 또는 항만공사)에 제출해야 합니다."
# },
# {
#     "QUESTION": "PORT-MIS 시스템을 통해 처리되는 주요 업무는 무엇인가요?",
#     "ANSWER": "PORT-MIS 시스템을 통해 처리되는 주요 업무는 선박의 입항·출항, 항만이용 및 항만물류, 해운·선원·선박 등의 민원사무 처리 및 정보관리입니다."
# },
# {
#     "QUESTION": "과오납 환급 신청서가 결재되기 전 어떤 과정을 거치나요?",
#     "ANSWER": "과오납 환급 신청서가 결재되기 전, 업무담당자는 민원인이 신청한 환급신청에 관한 서류를 확인하고, 상계/환급신청 메뉴를 통한 환급 계좌를 확인합니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS에서 제공하는 항만민원 서비스 중 선박운항관리에 포함되는 업무는 무엇인가요?",
#     "ANSWER": "PORT-MIS에서 제공하는 항만민원 서비스 중 선박운항관리에 포함되는 업무는 내외항선 선박입출항, 관제, 항만시설사용(선박), 예도선, 선박제원 등 선박운항관리 업무 지원 및 각종 정보 관리입니다."
# },
# {
#     "QUESTION": "PORT-MIS의 추진근거가 되는 법률 중 하나를 제시하세요.",
#     "ANSWER": "PORT-MIS의 추진근거가 되는 법률 중 하나는 「항만법」제26조(항만물류통합정보체계의 구축·운영)입니다."
# },
# {
#     "QUESTION": "PORT-MIS에서 제공하는 해운민원 서비스 중 선원관리에 포함되는 업무는 무엇인가요?",
#     "ANSWER": "PORT-MIS에서 제공하는 해운민원 서비스 중 선원관리에 포함되는 업무는 승하선 공인, 외국인선원고용신고, 선원수첩발급, 해기사면허발급, 선원자격증 발급, 승무경력증명발급 등 선원관리 업무 지원 및 각종 정보 관리입니다."
# },
# {
#     "QUESTION": "충남 지역에 있는 항만을 모두 나열하세요.",
#     "ANSWER": "충남 지역에 있는 항만은 태안항과 보령항입니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS 시스템이 처음 구축된 항만은 어디입니까?",
#     "ANSWER": "PORT-MIS 시스템이 처음 구축된 항만은 부산항입니다."
# },
# {
#     "QUESTION": "PORT-MIS EDI 서비스가 도입된 연도는 언제입니까?",
#     "ANSWER": "PORT-MIS EDI 서비스가 도입된 연도는 1996년입니다."
# },
# {
#     "QUESTION": "2018년에 실시된 PORT-MIS 서비스는 무엇입니까?",
#     "ANSWER": "2018년에 실시된 PORT-MIS 서비스는 통합 PORT-MIS 서비스입니다."
# },
# {
#     "QUESTION": "PORT-MIS 시스템을 이용하기 위해 필요한 자격은 무엇입니까?",
#     "ANSWER": "PORT-MIS 시스템을 이용하기 위해 필요한 자격은 해양수산부장관 또는 중계망사업자에게 민원처리를 위한 사용자계정을 부여 받은 이용자입니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS의 주요 목적은 무엇인가요?",
#     "ANSWER": "PORT-MIS의 주요 목적은 항만관련 통계정보의 수집, 사용료 조회 및 납부, 화물관리, 예도선 등 기타 민원 신청 및 결과 조회입니다."
# },
# {
#     "QUESTION": "PORT-MIS 재해복구시스템(DR)의 주요 기능은 무엇인가요?",
#     "ANSWER": "PORT-MIS 재해복구시스템(DR)의 주요 기능은 지진, 화재, 장애 등 각종 재해·재난 발생 시 해운항만물류정보시스템(PORT-MIS)의 중단 없는 서비스 제공입니다."
# },
# {
#     "QUESTION": "ebXML 민원신고와 EDI 민원신고의 주요 차이점은 무엇인가요?",
#     "ANSWER": "ebXML 민원신고는 민원업체가 직접 신고하며 송·수신 비용이 없고 다양한 상용기술을 활용할 수 있는 반면, EDI 민원신고는 중계망사업자를 통한 신고로 송·수신 비용이 발생하며 중계망사업자의 다양한 부가서비스를 활용할 수 있습니다."
# },
# {
#     "QUESTION": "PORT-MIS를 통해 모바일 민원신고를 할 때 제공되는 기능은 무엇인가요?",
#     "ANSWER": "PORT-MIS를 통해 모바일 민원신고를 할 때 제공되는 기능은 모바일을 통한 민원신고 및 신고 결과조회, 언제든 선박에 대한 관제현황 정보조회, EDI, ebXML 응답문서 조회 기능입니다."
# }
# ``````json
# {
#     "QUESTION": "해운항만물류정보시스템(PORT-MIS)의 운영 목적은 무엇인가요?",
#     "ANSWER": "해운항만물류정보시스템의 운영 목적은 해운항만물류정보시스템의 안정적인 운영·관리 및 365일 24시간 중단 없는 서비스 제공입니다."
# },
# {
#     "QUESTION": "해운항만물류정보 재해복구센터(DR)의 운영 방식은 어떻게 되나요?",
#     "ANSWER": "해운항만물류정보 재해복구센터(DR)는 공무원 2명과 위탁운영인력 10명이 연중무휴로 부산청내 재해복구센터에 상주하여 운영됩니다."
# },
# {
#     "QUESTION": "해운항만물류정보시스템(PORT-MIS) 운영 시 발생할 수 있는 단점은 무엇인가요?",
#     "ANSWER": "해운항만물류정보시스템(PORT-MIS) 운영 시 발생할 수 있는 단점은 초기 시스템 구축비용 발생과 EDI 이용량에 따른 이용료 부담입니다."
# },
# {
#     "QUESTION": "승객 명부 작성 시 어떤 항목에 체크해야 하나요?",
#     "ANSWER": "승객 명부 작성 시 입항(Arrival) 또는 출항(Departure), 최초(Notice), 변경(Change), 최종(Final), 취소(Cancel) 중 해당되는 곳에 √표를 해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "선박이 대한민국 항만에 입항하기 24시간 전까지 통보해야 하는 정보는 무엇인가요?",
#     "ANSWER": "선박이 대한민국 항만에 입항하기 24시간 전까지 통보해야 하는 정보는 선명, IMO 번호 또는 호출부호, 국적, 총톤수, 입항항만, 입항예정시각, 선박보안등급, (임시)국제선박보안증서 번호, 유효기간 및 발급기관명입니다."
# },
# {
#     "QUESTION": "선박의 입항횟수를 기록하는 항목의 이름은 무엇인가요?",
#     "ANSWER": "선박의 입항횟수를 기록하는 항목의 이름은 '해당 연도 입항횟수'입니다."
# },
# {
#     "QUESTION": "선박평형수 입항 보고서는 어떤 시스템을 통해 처리되나요?",
#     "ANSWER": "선박평형수 입항 보고서는 PORT-MIS 시스템을 통해 처리됩니다."
# },
# {
#     "QUESTION": "위험물 반입신고서에 포함되어야 하는 추가 문서는 무엇인가요?",
#     "ANSWER": "위험물 반입신고서에 포함되어야 하는 추가 문서는 '위험물 일람표'입니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS에서 디지털 고지서를 도입함으로써 어떤 이점이 있습니까?",
#     "ANSWER": "PORT-MIS에서 디지털 고지서를 도입함으로써 카톡/문자메시지(SMS)/이메일로 고지내용을 간편하게 확인할 수 있습니다."
# },
# {
#     "QUESTION": "최근 기항한 10개 항만에 대한 보안정보를 작성할 때 포함해야 하는 항목은 무엇입니까?",
#     "ANSWER": "최근 기항한 10개 항만에 대한 보안정보를 작성할 때 포함해야 하는 항목은 국가명, 항만명, 입출항일자, 선박의 보안등급, 항만의 보안등급, 특별한 또는 추가적인 보안조치 내용입니다."
# },
# {
#     "QUESTION": "PORT-MIS에서 고지서를 출력할 수 있는 주체는 누구입니까?",
#     "ANSWER": "PORT-MIS에서 고지서를 출력할 수 있는 주체는 민원인입니다."
# },
# {
#     "QUESTION": "특별한 또는 추가적인 보안조치가 있었다면 어떤 내용을 기술해야 합니까?",
#     "ANSWER": "특별한 또는 추가적인 보안조치가 있었다면, 일자와 항만명을 포함하여 그 내용을 기술해야 합니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS를 통해 항만시설 사용료를 납부할 때, 고지서를 출력하는 방법은 무엇인가요?",
#     "ANSWER": "PORT-MIS를 통해 항만시설 사용료를 납부할 때, 고지서를 출력하려면 '항만민원 ➡ 조회/발급/사용료 ➡ 사용료 ➡ [고지서 출력(민원인)] 메뉴를 선택'하여 출력할 고지서를 검색한 후, 리스트에서 원하는 출력대상을 선택하고 개별 고지서 출력을 클릭하여 미리보기 창에서 프린트 또는 pdf 파일 저장을 선택하면 됩니다."
# },
# {
#     "QUESTION": "PORT-MIS에서 고지되는 여러 건의 이용료를 어떻게 납부할 수 있나요?",
#     "ANSWER": "PORT-MIS에서 고지되는 여러 건의 이용료를 간편하게 디지털 방식으로 확인하고 한번에 납부할 수 있습니다. 납부대상을 선택한 후 결제방식을 선택하여 간편결제(비밀번호 입력) 또는 가상계좌 입금을 통해 여러 건을 통합납부할 수 있습니다."
# },
# {
#     "QUESTION": "PORT-MIS에서 고지서 발행 방식을 선택할 때, 어떤 발행 방식을 선택할 수 있나요?",
#     "ANSWER": "PORT-MIS에서 고지서 발행 방식을 선택할 때, 디지털 발행(카톡/이메일) 또는 민원인 출력(PORT-MIS)을 선택할 수 있습니다."
# },
# {
#     "QUESTION": "PORT-MIS를 통해 항만시설 사용료 납부 시 자동 알림 기능을 설정하려면 어떤 절차를 따라야 하나요?",
#     "ANSWER": "PORT-MIS를 통해 항만시설 사용료 납부 시 자동 알림 기능을 설정하려면 핸드폰, 이메일 번호를 등록하고, 알림방법을 선택하여 등록을 완료하면 됩니다. 이후 핸드폰 또는 이메일로 사용료 고지(취소) 정보 알림이 전송됩니다."
# }
# ``````json
# {
#     "QUESTION": "PORT-MIS에서 고지서를 출력하기 위해 어떤 절차를 따라야 합니까?",
#     "ANSWER": "PORT-MIS에서 고지서를 출력하기 위해서는 www.portmis.go.kr에 접속하여 항만민원 ➡ 조회/발급/사용료 ➡ 사용료 ➡ [사용료 납부확인서] 메뉴를 선택하고, 청코드, 업체코드, 납부일자 등 조회조건을 입력한 후 검색하여 리스트에서 원하는 출력대상을 선택하고, 납부확인서 출력 버튼을 클릭하여 미리보기 창에서 프린트 또는 pdf 파일저장을 선택하면 됩니다."
# },
# {
#     "QUESTION": "간편결제를 이용하기 위해 필요한 절차는 무엇입니까?",
#     "ANSWER": "간편결제를 이용하기 위해서는 로지스페이 서비스 신청, 이용업체 등록, 이용업체 승인, 결제 비밀번호 등록, 로지스페이 회원가입, 회원가입 승인, 간편결제 사용의 절차를 거쳐야 합니다."
# },
# {
#     "QUESTION": "가상계좌를 이용한 결제 방식의 특징은 무엇입니까?",
#     "ANSWER": "가상계좌를 이용한 결제 방식의 특징은 입금할 가상계좌가 부여되며, 입금을 별도로 처리해야 한다는 점입니다."
# },
# {
#     "QUESTION": "PORT-MIS에서 실시간 납부내역 확인이 가능한 이유는 무엇입니까?",
#     "ANSWER": "PORT-MIS에서 실시간 납부내역 확인이 가능한 이유는 온라인 결제 후 즉시 PORT-MIS에 자동으로 납부 처리되어 실시간 납부확인이 가능하기 때문입니다."
# }
# ``````json
# {
#     "QUESTION": "공지사항에 언급된 전화번호는 무엇입니까?",
#     "ANSWER": "공지사항에 언급된 전화번호는 1800-1172입니다."
# },
# {
#     "QUESTION": "해양수산부의 주소는 어디입니까?",
#     "ANSWER": "해양수산부의 주소는 세종특별자치시 다솜2로 94 정부세종청사 5동입니다."
# },
# {
#     "QUESTION": "자료실에 포함된 항목 중 하나를 말해보세요.",
#     "ANSWER": "자료실에 포함된 항목 중 하나는 FAQ입니다."
# },
# {
#     "QUESTION": "해양수산부의 웹사이트 주소는 무엇입니까?",
#     "ANSWER": "해양수산부의 웹사이트 주소는 www.mof.go.kr입니다."
# }
# ```

# %% [markdown]
# # jsonl 파일로 저장

# %%
# 문맥 함께 저장

# %%
import json

with open("qa_pair.jsonl", "w", encoding="utf-8") as f:
    for qa in qa_pair:
        f.write(json.dumps(qa, ensure_ascii=False) + "\n")

# %%
#데이터셋 업로드

# %%
from datasets import load_dataset
# JSONL 파일 경로
jsonl_file = "qa_pair.jsonl"
# JSONL 파일을 Dataset으로 로드
dataset = load_dataset("json", data_files=jsonl_file)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
from huggingface_hub import HfApi

# HfApi 인스턴스 생성
api = HfApi()

# 데이터셋을 업로드할 리포지토리 이름
repo_name = "ysm99/port-mis-data-ver2"

# 데이터셋을 허브에 푸시
dataset.push_to_hub(repo_name, token="허깅페이스토큰")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/342 [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/ysm99/port-mis-data-ver2/commit/ed79e692afb30aaa8a84a8e979072c63011b47b5', commit_message='Upload dataset', commit_description='', oid='ed79e692afb30aaa8a84a8e979072c63011b47b5', pr_url=None, pr_revision=None, pr_num=None)
